# %%
import sys, torch
print("Python:", sys.executable)
print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("GPU count:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Python: c:\Users\Mohvijay-sch\Desktop\NexusWatch\.venv\Scripts\python.exe
# Torch: 2.11.0+cu128
# CUDA available: True
# CUDA version: 12.8
# GPU count: 1
# GPU: NVIDIA RTX A6000

# %%
import torch

if torch.cuda.is_available():
    print(f"✅ GPU Found: {torch.cuda.get_device_name(0)}")
    total_vram_gb = torch.cuda.get_device_properties(0).total_memory / 1024**3
    print(f"📊 Total VRAM: {total_vram_gb:.2f} GB")
else:
    print("❌ GPU not detected. Check your NVIDIA drivers!")
# Out:
# ✅ GPU Found: NVIDIA RTX A6000
# 📊 Total VRAM: 44.99 GB

# %%
.\.venv\Scripts\python.exe data_audit.py "C:\Users\Mohvijay-sch\Desktop\NexusWatch\Dataset"
# Out:
#   Cell In[3], line 1
#     .\.venv\Scripts\python.exe data_audit.py "C:\Users\Mohvijay-sch\Desktop\NexusWatch\Dataset"
#     ^
# SyntaxError: invalid syntax
